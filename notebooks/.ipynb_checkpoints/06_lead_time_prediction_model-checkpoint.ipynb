# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import joblib

# %% [raw]
# Load Dataset

# %%
df = pd.read_csv(
    "../data/model_ready/model_ready_data.csv"
)

# %% [raw]
# Check dataset

# %%
df.shape
# Out:
# (10194, 48)

# %%
df.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  2024-01-03  2026-06-30
# 1       2  US-2021-112326-CHO-TRI-54000  2024-01-04  2026-07-01
# 2       3  US-2021-112326-CHO-NUT-13000  2024-01-04  2026-07-01
# 3       4  US-2021-112326-CHO-SCR-58000  2024-01-04  2026-07-01
# 4       5  US-2021-141817-CHO-TRI-54000  2024-01-05  2026-07-05
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code  ... Product_Encoded Region_Latitude Region_Longitude  \
# 0       77095  ...              10         39.0997         -94.5786
# 1       60540  ...              12         39.0997         -94.5786
# 2       60540  ...              11         39.0997         -94.5786
# 3       60540  ...              13         39.0997         -94.5786
# 4       19143  ...              12         40.7128         -74.0060
#
#   Shipping_Distance_KM  Distance_Category  Distance_Efficiency  \
# 0          1447.402305             Medium             0.581398
# 1          1447.402305             Medium             0.581398
# 2          1693.005751             Medium             0.510368
# 3          1693.005751             Medium             0.510368
# 4          1148.912517             Medium             0.667724
#
#    Factory_Avg_Distance  Route_Risk_Score  Distance_Profit_Ratio  \
# 0           2001.617854      1.315689e+06               0.002914
# 1           2001.617854      1.315689e+06               0.003383
# 2           1847.946642      1.538942e+06               0.004410
# 3           1847.946642      1.538942e+06               0.004427
# 4           2001.617854      1.047808e+06               0.006392
#
#    Route_Performance_Index
# 0                 0.377462
# 1                 0.379847
# 2                 0.364130
# 3                 0.354422
# 4                 0.436247
#
# [5 rows x 48 columns]

# %% [markdown]
# # Feature Selection

# %%
target = 'Lead_Time'

# %% [raw]
# Features

# %%
features = [

    'Sales',

    'Units',

    'Gross Profit',

    'Cost',

    'Profit_Margin',

    'Sales_Per_Unit',

    'Profit_Per_Unit',

    'Factory_Load',

    'Product_Demand',

    'Regional_Demand',

    'Route_Volume',

    'Factory_Efficiency',

    'Factory_Encoded',

    'Region_Encoded',

    'ShipMode_Encoded',

    'Product_Encoded',

    'Shipping_Distance_KM',

    'Distance_Efficiency',

    'Factory_Avg_Distance',

    'Route_Risk_Score',

    'Distance_Profit_Ratio',

    'Route_Performance_Index'
]

# %% [raw]
# X and Y

# %%
X = df[features]

y = df[target]

# %% [raw]
# Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(

    X,
    y,

    test_size=0.20,

    random_state=42
)

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

lr.fit(
    X_train,
    y_train
)
# Out:
# LinearRegression()

# %% [raw]
# Prediction

# %%
lr_pred = lr.predict(
    X_test
)

# %% [raw]
# Metrics

# %%
lr_mae = mean_absolute_error(
    y_test,
    lr_pred
)

lr_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        lr_pred
    )
)

lr_r2 = r2_score(
    y_test,
    lr_pred
)

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor(

    n_estimators=100,

    random_state=42
)

rf.fit(
    X_train,
    y_train
)
# Out:
# RandomForestRegressor(random_state=42)

# %% [raw]
# Prediction

# %%
rf_pred = rf.predict(
    X_test
)

# %% [raw]
# Metrics

# %%
rf_mae = mean_absolute_error(
    y_test,
    rf_pred
)

rf_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        rf_pred
    )
)

rf_r2 = r2_score(
    y_test,
    rf_pred
)

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingRegressor(

    random_state=42
)

gb.fit(
    X_train,
    y_train
)
# Out:
# GradientBoostingRegressor(random_state=42)

# %% [raw]
# Prediction

# %%
gb_pred = gb.predict(
    X_test
)

# %% [raw]
# Metrics

# %%
gb_mae = mean_absolute_error(
    y_test,
    gb_pred
)

gb_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        gb_pred
    )
)

gb_r2 = r2_score(
    y_test,
    gb_pred
)

# %% [markdown]
# # Model Comparison

# %%
results = pd.DataFrame({

    'Model': [

        'Linear Regression',

        'Random Forest',

        'Gradient Boosting'
    ],

    'MAE': [

        lr_mae,

        rf_mae,

        gb_mae
    ],

    'RMSE': [

        lr_rmse,

        rf_rmse,

        gb_rmse
    ],

    'R2': [

        lr_r2,

        rf_r2,

        gb_r2
    ]
})

results
# Out:
#                Model        MAE        RMSE        R2
# 0  Linear Regression  99.961419  130.577905  0.758902
# 1      Random Forest   0.526126    8.227195  0.999043
# 2  Gradient Boosting   7.505096   14.501373  0.997026

# %% [markdown]
# # Select Best Model

# %% [raw]
# Lowest RMSE
# Highest R²

# %% [markdown]
# # Feature Importance

# %%
importance = pd.DataFrame({

    'Feature': features,

    'Importance':
    rf.feature_importances_
})

# %% [raw]
# Sort

# %%
importance = importance.sort_values(

    by='Importance',

    ascending=False
)

# %% [raw]
# Top Features

# %%
importance.head(15)
# Out:
#                     Feature  Importance
# 19         Route_Risk_Score    0.762226
# 16     Shipping_Distance_KM    0.091731
# 17      Distance_Efficiency    0.089876
# 21  Route_Performance_Index    0.046367
# 12          Factory_Encoded    0.002610
# 18     Factory_Avg_Distance    0.002304
# 11       Factory_Efficiency    0.001135
# 13           Region_Encoded    0.000716
# 4             Profit_Margin    0.000569
# 10             Route_Volume    0.000504
# 7              Factory_Load    0.000318
# 15          Product_Encoded    0.000221
# 2              Gross Profit    0.000212
# 8            Product_Demand    0.000204
# 5            Sales_Per_Unit    0.000201

# %% [raw]
# Plot

# %%
import matplotlib.pyplot as plt

plt.figure(
    figsize=(10,6)
)

plt.barh(

    importance['Feature'].head(15),

    importance['Importance'].head(15)
)

plt.title(
    "Feature Importance"
)

plt.show()

# %% [markdown]
# # Save Best Model

# %%
joblib.dump(

    rf,

    "../models/lead_time_model.pkl"
)
# Out:
# ['../models/lead_time_model.pkl']

# %% [raw]
# Validation Examples

# %%
sample = X_test.head(5)

predictions = rf.predict(
    sample
)

pd.DataFrame({

    'Actual':
    y_test.head(5),

    'Predicted':
    predictions

})
# Out:
#        Actual  Predicted
# 6636     1269    1269.00
# 3742     1272    1271.96
# 5114     1273    1273.00
# 6505     1275    1275.00
# 10072    1640    1640.00

# %% [markdown]
# # Deliverables

# %% [raw]
# Best Model
# RMSE
# MAE
# R²
# Feature Importance
